# %%
from typing import TypedDict

class Person(TypeDict):
    name: str
    age: int

new_person: Person = {'name':'Eshan','age':23}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from typing import TypedDict
# ----> 3 class Person(TypeDict):
#       4     name: str
#       5     age: int
#
# NameError: name 'TypeDict' is not defined

# %%
from typing import TypedDict

# %%
class Person(TypeDict):
    name: str
    age: int

new_person: Person = {'name':'Eshan','age':23}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 class Person(TypeDict):
#       2     name: str
#       3     age: int
#
# NameError: name 'TypeDict' is not defined

# %%
from typing_extensions import TypedDict

class Person(TypedDict):
    name: str
    age: int

# %%
new_person: Person = {'name':'Eshan','age':23}

# %%
print(new_person)
# Out:
# {'name': 'Eshan', 'age': 23}

# %%
perosn1: {'name': 'Eshanjain','age': 34}
