# %%
# %run embedding_openai_query.py
# Out:
# 32
# [0.0059661865234375, -0.040008544921875, -0.04241943359375, 0.262939453125, -0.1419677734375, 0.368896484375, 0.2152099609375, -0.142822265625, -0.1512451171875, 0.2264404296875, -0.1090087890625, -0.024017333984375, -0.0172882080078125, -0.240478515625, 0.119873046875, -0.058624267578125, 0.058837890625, 0.0028514862060546875, 0.12457275390625, 0.08990478515625, -0.08624267578125, -0.07672119140625, 0.4521484375, -0.0311279296875, 0.241455078125, 0.2193603515625, -0.01459503173828125, -0.2247314453125, 0.203125, 0.2841796875, 0.0814208984375, 0.09710693359375]
# ...

# %%
# %run embedding_openai_docs.py
# Out:
# 3
# ...

# %%
# %run embedding_hf_lcoal.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\.conda\envs\ml_env\lib\site-packages\langchain_huggingface\embeddings\huggingface.py:68, in HuggingFaceEmbeddings.__init__(self, **kwargs)
#      67 try:
# ---> 68     import sentence_transformers  # type: ignore[import]
#      69 except ImportError as exc:
#
# ModuleNotFoundError: No module named 'sentence_transformers'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# File ~\AI Projects\Langchain and Rag\Embedded_models\embedding_hf_lcoal.py:3
#       1 from langchain_huggingface import HuggingFaceEmbeddings
# ----> 3 embedding = HuggingFaceEmbeddings(model_name = "sentence-transformers/all-MiniLM-L6-v2")
#       5 text = "Bhopal is the ca[ital of MP"
#       7 vector = embedding.embed_query(text)
#
# ...

# %%
# !pip install sentence-transformers
# Out:
# ...
#    ---------------------------------------- 0.0/739.6 kB ? eta -:--:--
#    ---------------------------------------- 739.6/739.6 kB 7.6 MB/s  0:00:00
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %run embedding_hf_lcoal.py
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 90.9MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# ...

# %%
# %run embedding_hf_docs.py
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# ...

# %%
# %run Document_similarity.py
# Out:
# tell me about Ms dhoni
# MS Dhoni is a former Indian captain famous for his calm demeanor and finishing skills.
# similarity score is: 0.6215607823439022
