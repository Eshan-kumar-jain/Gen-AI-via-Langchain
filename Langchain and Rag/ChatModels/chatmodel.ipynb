# %%
# %run chatmodel_openai_1.py
# Out:
# Akhand Bharat, also known as Undivided India, is a term used to refer to the dream of reunifying the territories of British India that were partitioned in 1947 into India, Pakistan, and later Bangladesh. The idea embodies cultural unity, harmonious coexistence, and shared historical, geographical, and architectural spaces. It is a subject of great significance and controversy in South Asian politics and history.

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\ESHAN JAIN\\AI Projects\\Langchain and Rag\\ChatModels'

# %%
# %run chatmodel_openai_2.py
# Out:
# temperature=0:
# Beneath the stadium's roaring swell,
# A dance of strength, a fierce ballet.
# In the heart of the game, passions dwell,
# Football, the warrior's modern play.
#
# temperature=0.3:
# In the field of dreams, we chase the ball,
# Under the sun, the moon, the rainfall.
# With every kick, every goal, every fall,
# Football, the greatest game of all.
#
# temperature=0.7:
# Under the stadium lights so bright,
# Football teams in the cool of night.
# With every pass, goal, and fight,
# Football is our heart's delight.
#
# temperature=1.0:
# On the pitch of emerald green,
# Battles fought, victories seen.
# A dance with the spherical muse,
# In football, we win or lose.
#
# temperature=1.3:
# With heartbeats akin to a drumroll's chat,
# In glory and defeat where heroes are born.
# Football unites, in unity decorously begat,
# It's not just a game, it's an emotion adorns.
#
# temperature=1.7:
# ...

# %%
# %run 4_chatmodel_hf_api.py
# Out:
# In Hindu mythology, a "chudail" or "chhayaal" (छायाळ) is a type of supernatural being, often referred to as a female demon or a witch. The term is commonly used in North Indian languages, including Hindi and Punjabi.
#
# In mythology, chudails are depicted as seductive and malevolent beings that can possess or charm people, often leading them into evil deeds or causing them harm. They are sometimes associated with the goddess Kali, who is considered to be a fierce and powerful female deity.
#
# In modern usage, the term "chudail" can also refer to a female witch or a sorceress in a more general sense, often with connotations of evil or malevolence. However, it's worth noting that the term's connotations can vary depending on the cultural and regional context in which it is used.
#
# ...

# %%
# %run 6_chatmodel_hf_local_ollama.py
# Out:
# A transformer is a crucial component in electrical engineering, and it's quite fascinating.
#
# **What is a Transformer?**
#
# A transformer is a static electrical device that transfers electrical energy from one circuit to another through electromagnetic induction. It's essentially a device that steps up or steps down the voltage of an alternating current (AC) electrical signal.
#
# **How Does a Transformer Work?**
#
# A transformer consists of two main parts:
#
# 1. **Primary coil**: This is the input coil that receives the electrical current.
# 2. **Secondary coil**: This is the output coil that delivers the transformed electrical current.
#
# Here's a simplified explanation of the process:
#
# 1. An alternating current (AC) flows into the primary coil, creating a magnetic field around it.
# 2. The magnetic field induces an electromotive force (EMF) in the secondary coil, causing a current to flow.
# ...

# %%
from huggingface_hub import whoami
print(whoami()["name"])
# Out:
# 7y767ut86

# %%
from huggingface_hub import constants
print(constants.HF_HOME)
print(constants.HF_TOKEN_PATH)

from pathlib import Path
print(Path(constants.HF_TOKEN_PATH).exists())
# Out:
# C:\Users\ESHAN JAIN\.cache\huggingface
# C:\Users\ESHAN JAIN\.cache\huggingface\token
# True

# %%
##from huggingface_hub import login
##login()

# %%
from pathlib import Path
from huggingface_hub import constants, whoami
print(Path(constants.HF_TOKEN_PATH).exists())   # want True
print(whoami()["name"])
# Out:
# True
# 7y767ut86

# %%
import torch
print(torch.cuda.is_available())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0),
          torch.cuda.get_device_properties(0).total_memory / 1e9, "GB")
# Out:
# True
# NVIDIA GeForce GTX 1650 4.294639616 GB
